# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
homicide = pd.read_excel('PDA Data.xlsx', sheet_name = 'Homicide')
crime = pd.read_excel('PDA Data.xlsx', sheet_name = 'Crime')
crude_suicide_rate = pd.read_excel('PDA Data.xlsx', sheet_name = 'Crude Suicide')
human_resource = pd.read_excel('PDA Data.xlsx', sheet_name = 'Human Resource')
age_standardize_suicide_rate = pd.read_excel('PDA Data.xlsx', sheet_name = 'Age Standardize Suicide Rate')
facilities = pd.read_excel('PDA Data.xlsx', sheet_name = 'Faculties')
mental_health_policy = pd.read_excel('PDA Data.xlsx', sheet_name = 'Mental health policy')
happiness = pd.read_excel('PDA Data.xlsx', sheet_name = 'Happiness')

# %%
homicide.head()
# Out:
#    Rank      Country  Value
# 0    45  Afghanistan    7.1
# 1    91      Albania    2.3
# 2   117      Algeria    1.4
# 3   167      Andorra    0.0
# 4    63       Angola    4.8

# %%
homicide.drop('Rank', axis = 1, inplace = True)
homicide.columns = ['Country', 'Homicide_Rate']

# %%
homicide.head()
# Out:
#        Country  Homicide_Rate
# 0  Afghanistan            7.1
# 1      Albania            2.3
# 2      Algeria            1.4
# 3      Andorra            0.0
# 4       Angola            4.8

# %%
homicide.sort_values('Homicide_Rate',ascending = False)
# Out:
#            Country  Homicide_Rate
# 46     El Salvador           61.8
# 73         Jamaica           57.0
# 165      Venezuela           56.3
# 62        Honduras           41.7
# 84         Lesotho           41.2
# ..             ...            ...
# 132      Singapore            0.2
# 86   Liechtenstein            0.0
# 3          Andorra            0.0
# 126     San Marino            0.0
# 96          Monaco            0.0
#
# [170 rows x 2 columns]

# %%
homicide['Homicide_Rate'].quantile([0,0.25,0.5,0.9,1])
# Out:
# 0.00     0.000
# 0.25     1.125
# 0.50     2.500
# 0.90    20.300
# 1.00    61.800
# Name: Homicide_Rate, dtype: float64

# %%
def high_low(x):
    a=[]
    for i in x:
        if i<=x.quantile(0.25):
            a.append('Very Low')
        elif (i>=x.quantile(0.25)) and (i<x.quantile(0.5)):
            a.append('Low')
        elif (i>=x.quantile(0.5)) and (i<x.quantile(0.75)):
            a.append('High')
        else:
            a.append('Very High')
    return a

# %%
homicide['Homicide_Level'] = high_low(homicide['Homicide_Rate'])

# %%
homicide.head()
# Out:
#        Country  Homicide_Rate Homicide_Level
# 0  Afghanistan            7.1           High
# 1      Albania            2.3            Low
# 2      Algeria            1.4            Low
# 3      Andorra            0.0       Very Low
# 4       Angola            4.8           High

# %%
crime.head()
# Out:
#        Country  Crime Index  2021 Population
# 0  Afghanistan        76.31          39835428
# 1      Albania        42.53           2872933
# 2      Algeria        52.03          44616624
# 3       Angola        66.48          33933610
# 4    Argentina        63.82          45605826

# %%
crime.columns = ['Country', 'Crime_Index', 'Population']

# %%
crime['Crime_Level'] = high_low(crime['Crime_Index'])

# %%
crime.head()
# Out:
#        Country  Crime_Index  Population Crime_Level
# 0  Afghanistan        76.31    39835428   Very High
# 1      Albania        42.53     2872933         Low
# 2      Algeria        52.03    44616624        High
# 3       Angola        66.48    33933610   Very High
# 4    Argentina        63.82    45605826   Very High

# %%
crude_suicide_rate.head()
# Out:
#        Country          Sex   80_above   70to79   60to69    50to59    40to49  \
# 0  Afghanistan   Both sexes       42.0     11.0       5.5       5.6      6.6
# 1  Afghanistan         Male       70.4     20.9       9.8       9.3     10.5
# 2  Afghanistan       Female       20.1      2.3       1.4       1.6      2.3
# 3      Albania   Both sexes       16.3      8.3       6.0       7.8      9.1
# 4      Albania         Male       23.2     11.9       8.1      11.4     13.5
#
#     30to39   20to29   10to19
# 0      9.2     10.2      3.1
# 1     15.1     16.3      4.8
# 2      2.7      3.5      1.2
# 3      6.1      6.5      5.0
# 4      8.8      6.3      3.1

# %%
crude_suicide_rate_total = crude_suicide_rate[crude_suicide_rate['Sex'] == ' Both sexes']
crude_suicide_rate_total.reset_index(drop = True, inplace = True)
crude_suicide_rate_male = crude_suicide_rate[crude_suicide_rate['Sex'] == ' Male']
crude_suicide_rate_male.reset_index(drop = True, inplace = True)
crude_suicide_rate_female = crude_suicide_rate[crude_suicide_rate['Sex'] == ' Female']
crude_suicide_rate_female.reset_index(drop = True, inplace = True)
crude_suicide_rate_total.head()
# Out:
#                Country          Sex   80_above   70to79   60to69    50to59   \
# 0          Afghanistan   Both sexes       42.0     11.0       5.5       5.6
# 1              Albania   Both sexes       16.3      8.3       6.0       7.8
# 2              Algeria   Both sexes        9.4      5.6       4.2       4.1
# 3               Angola   Both sexes       63.5     42.1      23.8      14.8
# 4  Antigua and Barbuda   Both sexes        0.0      0.0       8.1       0.0
#
#     40to49   30to39   20to29   10to19
# 0      6.6      9.2     10.2      3.1
# 1      9.1      6.1      6.5      5.0
# 2      4.7      5.3      4.2      1.3
# 3      7.0      5.4      6.6      2.6
# 4      0.0      0.0      0.0      0.0

# %%
crude_suicide_rate_total.drop('Sex', axis = 1, inplace = True)
crude_suicide_rate_female.drop('Sex', axis = 1, inplace = True)
crude_suicide_rate_male.drop('Sex', axis = 1, inplace = True)

# %%
crude_suicide_rate_female.head()
# Out:
#                Country   80_above   70to79   60to69    50to59    40to49  \
# 0          Afghanistan       20.1      2.3       1.4       1.6      2.3
# 1              Albania       10.9      4.9       3.9       4.4      5.0
# 2              Algeria        6.4      3.0       2.2       2.0      2.4
# 3               Angola       25.3     21.7      14.5       8.6      3.5
# 4  Antigua and Barbuda        0.0      0.0      15.8       0.0      0.0
#
#     30to39   20to29   10to19
# 0      2.7      3.5      1.2
# 1      3.4      6.6      7.0
# 2      2.6      2.1      1.0
# 3      2.5      2.9      1.4
# 4      0.0      0.0      0.0

# %%
crude_suicide_rate_female.columns = ['Country'] + ['crude_suicide_'+ i.strip() +'_female' for i in crude_suicide_rate_female.columns[1:]]
crude_suicide_rate_male.columns = ['Country'] + ['crude_suicide_'+ i.strip() +'_male' for i in crude_suicide_rate_male.columns[1:]]
crude_suicide_rate_total.columns = ['Country'] + ['crude_suicide_'+ i.strip() for i in crude_suicide_rate_total.columns[1:]]

# %%
crude_suicide = crude_suicide_rate_total.merge(crude_suicide_rate_male.merge(crude_suicide_rate_female, on = 'Country'),
                                               on = 'Country')
crude_suicide.head()
# Out:
#                Country  crude_suicide_80_above  crude_suicide_70to79  \
# 0          Afghanistan                    42.0                  11.0
# 1              Albania                    16.3                   8.3
# 2              Algeria                     9.4                   5.6
# 3               Angola                    63.5                  42.1
# 4  Antigua and Barbuda                     0.0                   0.0
#
#    crude_suicide_60to69  crude_suicide_50to59  crude_suicide_40to49  \
# 0                   5.5                   5.6                   6.6
# 1                   6.0                   7.8                   9.1
# 2                   4.2                   4.1                   4.7
# 3                  23.8                  14.8                   7.0
# 4                   8.1                   0.0                   0.0
#
#    crude_suicide_30to39  crude_suicide_20to29  crude_suicide_10to19  \
# 0                   9.2                  10.2                   3.1
# ...

# %%
human_resource.head()
# Out:
#                Country  Psychiatrists  Nurses  Social_workers  Psychologists
# 0          Afghanistan          0.231   0.098             NaN          0.296
# 1              Albania          1.471   6.876           1.060          1.231
# 2               Angola          0.057   0.660           0.022          0.179
# 3  Antigua and Barbuda          1.001   7.005           4.003            NaN
# 4            Argentina         21.705     NaN             NaN        222.572

# %%
age_standardize_suicide_rate.columns
# Out:
# Index(['Country', 'Sex', 2016, 2015, 2010, 2000], dtype='object')

# %%
age_standardize_suicide_rate = age_standardize_suicide_rate.iloc[:, [0,1,2]]
age_standardize_suicide_rate.columns = ['Country', 'Sex', 'Age_Standardized_Suicide_Rate']

# %%
age_standardize_suicide_rate.head()
# Out:
#        Country          Sex  Age_Standardized_Suicide_Rate
# 0  Afghanistan   Both sexes                            6.4
# 1  Afghanistan         Male                           10.6
# 2  Afghanistan       Female                            2.1
# 3      Albania   Both sexes                            5.6
# 4      Albania         Male                            7.0

# %%
age_standardize_suicide_rate = pd.pivot(age_standardize_suicide_rate, index = 'Country', columns = 'Sex')
age_standardize_suicide_rate.reset_index(inplace = True)

# %%
age_standardize_suicide_rate.columns = ['Country', 'Age_Standardized_Suicide_Rate', 'Age_Standardized_Suicide_Rate_Female', 
                                       'Age_Standardized_Suicide_Rate_Male']

# %%
age_standardize_suicide_rate.head()
# Out:
#                Country  Age_Standardized_Suicide_Rate  \
# 0          Afghanistan                            6.4
# 1              Albania                            5.6
# 2              Algeria                            3.3
# 3               Angola                            8.9
# 4  Antigua and Barbuda                            0.5
#
#    Age_Standardized_Suicide_Rate_Female  Age_Standardized_Suicide_Rate_Male
# 0                                   2.1                                10.6
# 1                                   4.3                                 7.0
# 2                                   1.8                                 4.9
# 3                                   4.6                                14.0
# 4                                   0.9                                 0.0

# %%
facilities.head()
# Out:
#                Country  Year  Mental _hospitals  health_units  \
# 0          Afghanistan  2016              0.003         0.012
# 1              Albania  2016              0.068         0.068
# 2              Algeria  2016              0.048         0.068
# 3               Angola  2016              0.011           NaN
# 4  Antigua and Barbuda  2016              1.001           NaN
#
#    outpatient _facilities  day _treatment  residential_facilities
# 0                   0.006             NaN                     NaN
# 1                   0.410             NaN                   0.445
# 2                   0.048             NaN                     NaN
# 3                     NaN             NaN                   0.014
# 4                     NaN             NaN                     NaN

# %%
facilities.drop('Year', axis = 1, inplace = True)

# %%
mental_health_policy.head()
# Out:
#                Country Stand-alone law for mental health  \
# 0          Afghanistan                               Yes
# 1              Albania                               Yes
# 2              Algeria                               Yes
# 3               Angola                                No
# 4  Antigua and Barbuda                               Yes
#
#   Stand-alone policy or plan for mental health
# 0                                          Yes
# 1                                          Yes
# 2                                           No
# 3                                           No
# 4                                          Yes

# %%
mental_health_policy.columns = ['Country', 'Stand_alone_law_for_mental_health', 'Stand_alone_policy_for_mental_health' ]

# %%
def clean(x):
    a=[]
    for i in x:
        i = i.title()
        i = i.strip()
        a.append(i)
    return a

# %%
mental_health_policy['Stand_alone_law_for_mental_health'] = clean(mental_health_policy['Stand_alone_law_for_mental_health'])
mental_health_policy['Stand_alone_policy_for_mental_health'] = clean(mental_health_policy['Stand_alone_policy_for_mental_health'])

# %%
happiness.head()
# Out:
#   Country name                  Regional indicator  Ladder score  \
# 0  Afghanistan                          South Asia        2.5669
# 1      Albania          Central and Eastern Europe        4.8827
# 2      Algeria        Middle East and North Africa        5.0051
# 3    Argentina         Latin America and Caribbean        5.9747
# 4      Armenia  Commonwealth of Independent States        4.6768
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                        0.031311      2.628270      2.505530
# 1                        0.056116      4.992687      4.772713
# 2                        0.044236      5.091802      4.918397
# 3                        0.053442      6.079446      5.869954
# 4                        0.058595      4.791646      4.561953
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0               7.462861        0.470367                52.590000
# ...

# %%
happiness.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
happiness.drop([ 'Standard error of ladder score', 'upperwhisker', 'lowerwhisker','Ladder score in Dystopia',
       'Explained by: Log GDP per capita', 'Explained by: Social support',
       'Explained by: Healthy life expectancy',
       'Explained by: Freedom to make life choices',
       'Explained by: Generosity', 'Explained by: Perceptions of corruption',
       'Dystopia + residual'], axis = 1, inplace = True)

# %%
happiness.columns = ['Country', 'Regional_indicator', 'Happiness_Score', 'GDP_Per_Capita','Social_support',
                     'Healthy_life_expectancy','Freedom_to_make_life_choices', 'Generosity','Perceptions_of_corruption']

# %%
happiness['Social_Support_Level'] = high_low(happiness['Social_support'])
happiness['Generosity_Level'] = high_low(happiness['Generosity'])
happiness['Freedom_to_make_life_choices_level'] = high_low(happiness['Freedom_to_make_life_choices'])

# %%
happiness.head()
# Out:
#        Country                  Regional_indicator  Happiness_Score  \
# 0  Afghanistan                          South Asia           2.5669
# 1      Albania          Central and Eastern Europe           4.8827
# 2      Algeria        Middle East and North Africa           5.0051
# 3    Argentina         Latin America and Caribbean           5.9747
# 4      Armenia  Commonwealth of Independent States           4.6768
#
#    GDP_Per_Capita  Social_support  Healthy_life_expectancy  \
# 0        7.462861        0.470367                52.590000
# 1        9.417931        0.671070                68.708138
# 2        9.537965        0.803385                65.905174
# 3        9.810955        0.900568                68.803802
# 4        9.100476        0.757479                66.750656
#
#    Freedom_to_make_life_choices  Generosity  Perceptions_of_corruption  \
# 0                      0.396573   -0.096429                   0.933687
# ...

# %%
dataframes = [homicide, age_standardize_suicide_rate, crime, crude_suicide, facilities, happiness, 
              human_resource, mental_health_policy]
dataframes_1 = [age_standardize_suicide_rate, crude_suicide, happiness]

# %%
for i in dataframes:
    i['Country'] = [j.lower().strip() for j in i['Country']]

# %%
from functools import reduce

# %%
df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['Country'],
                                            how='inner'), dataframes_1)

# %%
for i in [homicide, crime, facilities, human_resource, mental_health_policy]:
    df_merged = df_merged.merge(i, how = 'left', on = 'Country')

# %%
df_merged.shape
# Out:
# (142, 55)

# %%
df_merged.head(20)
# Out:
#                    Country  Age_Standardized_Suicide_Rate  \
# 0              afghanistan                            6.4
# 1                  albania                            5.6
# 2                  algeria                            3.3
# 3                argentina                            9.1
# 4                  armenia                            5.7
# 5                australia                           11.7
# 6                  austria                           11.4
# 7               azerbaijan                            2.6
# 8                  bahrain                            5.7
# 9               bangladesh                            6.1
# 10                 belarus                           21.4
# 11                 belgium                           15.7
# 12                   benin                           15.7
# 13                 bolivia                           12.9
# 14  bosnia and herzegovina                            6.4
# ...

# %%
df_merged.to_csv("Mental Health VS Happiness Rate.csv", index = False)

# %%
print(df_merged.columns)
# Out:
# Index(['Country', 'Age_Standardized_Suicide_Rate',
#        'Age_Standardized_Suicide_Rate_Female',
#        'Age_Standardized_Suicide_Rate_Male', 'crude_suicide_80_above',
#        'crude_suicide_70to79', 'crude_suicide_60to69', 'crude_suicide_50to59',
#        'crude_suicide_40to49', 'crude_suicide_30to39', 'crude_suicide_20to29',
#        'crude_suicide_10to19', 'crude_suicide_80_above_male',
#        'crude_suicide_70to79_male', 'crude_suicide_60to69_male',
#        'crude_suicide_50to59_male', 'crude_suicide_40to49_male',
#        'crude_suicide_30to39_male', 'crude_suicide_20to29_male',
#        'crude_suicide_10to19_male', 'crude_suicide_80_above_female',
#        'crude_suicide_70to79_female', 'crude_suicide_60to69_female',
#        'crude_suicide_50to59_female', 'crude_suicide_40to49_female',
#        'crude_suicide_30to39_female', 'crude_suicide_20to29_female',
#        'crude_suicide_10to19_female', 'Regional_indicator', 'Happiness_Score',
# ...
